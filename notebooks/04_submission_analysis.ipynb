# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### exp001

# %%
with open("../outputs/exp001/metrics.json", "r", encoding="utf-8") as f:
    metrics = json.load(f)

oof = pd.read_csv("../outputs/exp001/oof.csv")

y_true = oof["target"]
pred_label = (oof["prediction"] > metrics["best_threshold"]).astype(int)

cm = confusion_matrix(y_true, pred_label)

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.savefig('images/exp001_cnfusion_matrix.png')
plt.close()

# %%
print(f'適合率: {cm[1,1] / sum(cm[:, 1])}')
print(f'再現率: {cm[1,1] / sum(cm[1, :])}')
# Out:
# 適合率: 0.595
# 再現率: 0.664804469273743
